# %% [markdown]
# # IA - Algoritmos de Busca (Exercícios)

# %% [markdown]
# ## Importações

# %%
import numpy as np
from numpy import random
import random
import pandas as pd
from math import sqrt
import networkx as nx
from collections import deque
import time

# %%
#!pip install geopandas

# %% [markdown]
# ## Funções

# %%
G = nx.Graph()

# %%
G.add_weighted_edges_from([
        ("Arad", "Sibiu", 140),
        ("Arad", "Timisoara", 118),
        ("Arad", "Zerind", 75),
        ("Bucharest", "Fagaras", 211),
        ("Bucharest", "Giurgiu", 90),
        ("Bucharest", "Pitesti", 101),
        ("Bucharest", "Urziceni", 85),
        ("Craiova", "Dobreta", 120),
        ("Craiova", "Pitesti", 138),
        ("Craiova", "Rimnicu_Vilcea", 146),
        ("Dobreta", "Mehadia", 75),
        ("Eforie", "Hirsova", 86),
        ("Fagaras", "Sibiu", 99),
        ("Hirsova", "Urziceni", 98),
        ("Iasi", "Neamt", 87),
        ("Iasi", "Vaslui", 92),
        ("Lugoj", "Mehadia", 70),
        ("Lugoj", "Timisoara", 111),
        ("Oradea", "Zerind", 71),
        ("Oradea", "Sibiu", 151),
        ("Pitesti", "Rimnicu_Vilcea", 97),
        ("Rimnicu_Vilcea", "Sibiu", 80),
        ("Urziceni", "Vaslui", 142)
    ])

# %%
nx.draw_networkx(G, with_labels=True)

# %%
Heuristics = [
        ("Arad", 366),
        ("Bucharest", 0),
        ("Craiova", 160),
        ("Dobreta", 242),
        ("Eforie", 161),
        ("Fagaras", 178),
        ("Giurgiu", 77),
        ("Hirsova", 151),
        ("Iasi", 226),
        ("Lugoj", 244),
        ("Mehadia", 241),
        ("Neamt", 234),
        ("Oradea", 380),
        ("Pitesti", 98),
        ("Rimnicu_Vilcea", 193),
        ("Sibiu", 253),
        ("Timisoara", 329),
        ("Urziceni", 80),
        ("Vaslui", 199),
        ("Zerind", 374)
    ]

# %%
heuristics_dict = {k: v for k, v in Heuristics}

# %% [markdown]
# ## Algoritmo BFS

# %%
# Implemente aqui o algoritmo BFS

# %%
G.nodes()
# Out:
# NodeView(('Arad', 'Sibiu', 'Timisoara', 'Zerind', 'Bucharest', 'Fagaras', 'Giurgiu', 'Pitesti', 'Urziceni', 'Craiova', 'Dobreta', 'Rimnicu_Vilcea', 'Mehadia', 'Eforie', 'Hirsova', 'Iasi', 'Neamt', 'Vaslui', 'Lugoj', 'Oradea'))

# %%
def __BFS(G, s):
    # INICIALIZACAO
    for v in G.nodes() - {s}:
        G.nodes[v]['cor'] = 'branco'
        G.nodes[v]['dis'] = np.inf

    G.nodes[s]['cor'] = 'cinza'
    G.nodes[s]['dis'] = 0

    # Fila (append (right), popleft)
    Q = deque()
    Q.append(s)
    while len(Q) != 0:
        u = Q.popleft()

        for v in G.neighbors(u):
            if G.nodes[v]['cor'] == 'branco':
                G.nodes[v]['cor'] = 'cinza'
                G.nodes[v]['dis'] = G.nodes[u]['dis'] + 1
                G.nodes[v]['pre'] = u

                Q.append(v)

        G.nodes[u]['cor'] = 'preto'

        #print(u, G.nodes[u]['dis'], G.nodes[u]['cor'])

    
def __caminho_minimo(G, s, t):

    L = [t]
    u = t
    while u != s:
        u = G.nodes[u]['pre']
        L.append(u)

    L.reverse()

    return L

def BFS(G, s, t):
    __BFS(G, s)
    return __caminho_minimo(G, s, t)

# %%
BFS(G, 'Arad', 'Bucharest')
# __caminho_minimo(G, 'Arad', 'Bucharest')
# Out:
# ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']

# %% [markdown]
# ## Algoritmo UCS (Custo Uniforme)

# %%
# Implemente aqui o algoritmo UCS (Custo Uniforme)

# %%
def __UCS(graph, source, target, log=False):
  for v in graph.nodes():
        graph.nodes[v]['cor'] = 'branco'
        graph.nodes[v]['dis'] = 0

  graph.nodes[source]["cor"] = "cinza"

  queue = [source]
  finished = False
  best = None

  while(len(queue) > 0 and not finished):
    city = queue.pop(0)
    node = graph.nodes[city]
    node["cor"] = "amarelo"
    for neighbor_city in graph.neighbors(city):
      neighbor_node = graph.nodes[neighbor_city]
      distance = node["dis"] + G.adj[city][neighbor_city]["weight"]
      if neighbor_node["cor"] == "branco" or (best and best["dis"] > distance and neighbor_city == target):
        neighbor_node["cor"] = "vermelho"
        neighbor_node["dis"] = distance
        neighbor_node["pre"] = city
        queue.append(neighbor_city)
        if log:
          print(f"{city} => {neighbor_city} ({neighbor_node['dis']})")
        if neighbor_city == target:
          best = neighbor_node
    if log:
      print("=" * 8)

    queue = sorted(queue, key=lambda d: graph.nodes[d]['dis'])


def __caminho_minimo(G, s, t):

    L = [t]
    u = t
    while u != s:
        u = G.nodes[u]['pre']
        L.append(u)

    L.reverse()

    return L



def UCS(G, s, t, log=False):
    __UCS(G, s, t, log)
    total_dis = G.nodes[t]["dis"]
    print("Total cost:", total_dis)
    return __caminho_minimo(G, s, t)

# %%
start_time = time.time()
UCS(G, 'Arad', 'Bucharest', log=True)
end_time = time.time()
# Out:
# Arad => Sibiu (140)
# Arad => Timisoara (118)
# Arad => Zerind (75)
# ========
# Zerind => Oradea (146)
# ========
# Timisoara => Lugoj (229)
# ========
# Sibiu => Fagaras (239)
# Sibiu => Rimnicu_Vilcea (220)
# ========
# ========
# Rimnicu_Vilcea => Craiova (366)
# Rimnicu_Vilcea => Pitesti (317)
# ========
# Lugoj => Mehadia (299)
# ========
# Fagaras => Bucharest (450)
# ========
# Mehadia => Dobreta (374)
# ========
# Pitesti => Bucharest (418)
# ========
# ========
# ========
# Bucharest => Giurgiu (508)
# Bucharest => Urziceni (503)
# ========
# ========
# Urziceni => Hirsova (601)
# Urziceni => Vaslui (645)
# ========
# ========
# Hirsova => Eforie (687)
# ========
# Vaslui => Iasi (737)
# ========
# ========
# Iasi => Neamt (824)
# ========
# ========
# Total cost: 418
# ['Arad', 'Sibiu', 'Rimnicu_Vilcea', 'Pitesti', 'Bucharest']

# %% [markdown]
# ## Algoritmo A-star

# %%
# Implemente aqui o algoritmo A-star

# %%
def __ASTAR(graph, source, target, log=False):
  for v in graph.nodes():
        graph.nodes[v]['cor'] = 'branco'
        graph.nodes[v]['dis'] = 0
        graph.nodes[v]['gh'] = 0
        graph.nodes[v]['cost'] = 0

  graph.nodes[source]["cor"] = "cinza"

  queue = [source]
  best = None

  while(len(queue) > 0):
    city = queue.pop(0)
    node = graph.nodes[city]
    node["cor"] = "amarelo"
    for neighbor_city in graph.neighbors(city):
      neighbor_node = graph.nodes[neighbor_city]
      distance = node["dis"] + G.adj[city][neighbor_city]["weight"]
      gh = node["dis"] + heuristics_dict[neighbor_city]
      if neighbor_node["cor"] == "branco" or (best and best["cost"] > (distance + gh) and neighbor_city == target):
        neighbor_node["cor"] = "vermelho"
        neighbor_node["dis"] = distance
        neighbor_node["gh"] = gh
        neighbor_node["cost"] = distance + gh
        neighbor_node["pre"] = city
        queue.append(neighbor_city)
        if log:
          print(f"{city} => {neighbor_city}. Dis: ({neighbor_node['dis']}). GH: ({neighbor_node['gh']}). Cost: ({neighbor_node['cost']})")
        if neighbor_city == target:
          best = neighbor_node
    if log:
      print("=" * 8)

    queue = sorted(queue, key=lambda d: graph.nodes[d]['cost'])


def __caminho_minimo(G, s, t):

    L = [t]
    u = t
    while u != s:
        u = G.nodes[u]['pre']
        L.append(u)

    L.reverse()

    return L



def ASTAR(G, s, t, log=False):
    __ASTAR(G, s, t, log)
    total_dis = G.nodes[t]["dis"]
    print("Total cost:", total_dis)
    return __caminho_minimo(G, s, t)

# %%
ASTAR(G, 'Arad', 'Bucharest', log=True)
# Out:
# Arad => Sibiu. Dis: (140). GH: (253). Cost: (393)
# Arad => Timisoara. Dis: (118). GH: (329). Cost: (447)
# Arad => Zerind. Dis: (75). GH: (374). Cost: (449)
# ========
# Sibiu => Fagaras. Dis: (239). GH: (318). Cost: (557)
# Sibiu => Oradea. Dis: (291). GH: (520). Cost: (811)
# Sibiu => Rimnicu_Vilcea. Dis: (220). GH: (333). Cost: (553)
# ========
# Timisoara => Lugoj. Dis: (229). GH: (362). Cost: (591)
# ========
# ========
# Rimnicu_Vilcea => Craiova. Dis: (366). GH: (380). Cost: (746)
# Rimnicu_Vilcea => Pitesti. Dis: (317). GH: (318). Cost: (635)
# ========
# Fagaras => Bucharest. Dis: (450). GH: (239). Cost: (689)
# ========
# Lugoj => Mehadia. Dis: (299). GH: (470). Cost: (769)
# ========
# ========
# Bucharest => Giurgiu. Dis: (540). GH: (527). Cost: (1067)
# Bucharest => Urziceni. Dis: (535). GH: (530). Cost: (1065)
# ========
# Craiova => Dobreta. Dis: (486). GH: (608). Cost: (1094)
# ========
# ========
# ========
# Urziceni => Hirsova. Dis: (633). GH: (686). Cost: (1319)
# Urziceni => Vaslui. Dis: (677). GH: (734). Cost: (1411)
# ========
# ========
# ========
# Hirsova => Eforie. Dis: (719). GH: (794). Cost: (1513)
# ========
# Vaslui => Iasi. Dis: (769). GH: (903). Cost: (1672)
# ========
# ========
# Iasi => Neamt. Dis: (856). GH: (1003). Cost: (1859)
# ========
# ========
# Total cost: 450
# ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']

# %% [markdown]
# ## Programa Principal

# %%
# Chame aqui apropriadamente os algoritmos para resolver o problema
